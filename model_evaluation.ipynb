# %%
# %%capture

import math
import pandas as pd
import numpy as np
from tqdm import notebook
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, push_notebook, show
import matplotlib.pyplot as plt
from datetime import date, datetime
from tqdm.notebook import tqdm
import re
import xgboost as xgb
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
import matplotlib.pyplot as pl
import xgboost as xgb
import sklearn.metrics
from matplotlib import pyplot

#notebook.tqdm(looping)

try:
    # %load_ext autotime
    # %load_ext jupyterlab_notify
except:
    # !pip3 install ipython-autotime
    # %load_ext autotime
# Out:
# time: 1.27 s (started: 2021-09-11 22:50:01 -04:00)

# %%
import pickle
file_name = "xgb_sma_tuned.pkl"

xgb_model = pickle.load(open(file_name, "rb"))
# Out:
# time: 1.84 ms (started: 2021-09-11 23:17:44 -04:00)

# %%
results = xgb_model.evals_result()
# plot learning curves
plt.plot(results['validation_0']['logloss'], label='train')
plt.plot(results['validation_1']['logloss'], label='test')
# show the legend
plt.legend()
# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_38667/499688582.py in <module>
# ----> 1 results = xgb_model.evals_result()
#       2 # plot learning curves
#       3 plt.plot(results['validation_0']['logloss'], label='train')
#       4 plt.plot(results['validation_1']['logloss'], label='test')
#       5 # show the legend
#
# ~/.local/lib/python3.9/site-packages/xgboost/sklearn.py in evals_result(self)
#    1319             'validation_1': {'logloss': ['0.41965', '0.17686']}}
#    1320         """
# -> 1321         if self.evals_result_:
#    1322             evals_result = self.evals_result_
#    1323         else:
#
# AttributeError: 'XGBClassifier' object has no attribute 'evals_result_'
# time: 6.45 ms (started: 2021-09-10 17:59:04 -04:00)

# %%
plt.rcParams["figure.figsize"] = (10,50)
xgb.plot_importance(xgb_model)
pl.title("xgboost.plot_importance(model)")
pl.show()
# Out:
# time: 699 ms (started: 2021-09-11 23:17:46 -04:00)

# %%
import optuna
import joblib
study = joblib.load('optuna.pkl')
optuna.visualization.plot_param_importances(study)

# %%
optuna.visualization.plot_optimization_history(study)

# %%
optuna.visualization.plot_parallel_coordinate(study)
